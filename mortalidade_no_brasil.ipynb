# %% [markdown]
# ## Importações

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv("/home/iris/mortalidade_no_brasil_cdd/DO23OPEN.csv", delimiter=";", encoding="utf-8")
# Out:
# /tmp/ipykernel_210256/3094678107.py:1: DtypeWarning: Columns (65) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/home/iris/mortalidade_no_brasil_cdd/DO23OPEN.csv", delimiter=";", encoding="utf-8")

# %% [markdown]
# ## Inspeção Inicial dos Dados, Pré-processamento, limpeza, transformações, etc

# %%
df.head()
# Out:
#    contador  ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU  \
# 0         1       1         2  14022023     1300.0    823.0    231025.0
# 1         2       1         2  14022023     1435.0    833.0    330455.0
# 2         3       1         2  14022023       40.0    833.0    330000.0
# 3         4       1         2  14022023      700.0    826.0    260890.0
# 4         5       1         2  14022023     1620.0    821.0    211130.0
#
#        DTNASC  IDADE  SEXO  ...  TPRESGINFO  TPNIVELINV  DTCADINF  MORTEPARTO  \
# 0   4081955.0  467.0     2  ...         NaN         NaN       NaN         NaN
# 1  28031985.0  437.0     2  ...         NaN         NaN       NaN         NaN
# 2  27091996.0  426.0     2  ...         NaN           M       NaN         NaN
# 3   8031937.0  485.0     2  ...         NaN         NaN       NaN         NaN
# 4  30031963.0  459.0     1  ...         NaN         NaN       NaN         NaN
#
#    DTCONCASO  ALTCAUSA  CAUSABAS_O  TPPOS  TP_ALTERA  CB_ALT
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1485653 entries, 0 to 1485652
# Data columns (total 86 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   contador    1485653 non-null  int64
#  1   ORIGEM      1485653 non-null  int64
#  2   TIPOBITO    1485653 non-null  int64
#  3   DTOBITO     1485653 non-null  int64
#  4   HORAOBITO   1435577 non-null  float64
#  5   NATURAL     1417155 non-null  float64
#  6   CODMUNNATU  1398650 non-null  float64
#  7   DTNASC      1456411 non-null  float64
#  8   IDADE       1459167 non-null  float64
#  9   SEXO        1485653 non-null  int64
#  10  RACACOR     1436087 non-null  float64
#  11  ESTCIV      1393298 non-null  float64
#  12  ESC         1370139 non-null  float64
#  13  ESC2010     1361327 non-null  float64
#  14  SERIESCFAL  403412 non-null   float64
#  15  OCUP        1257368 non-null  float64
#  16  CODMUNRES   1485653 non-null  int64
# ...

# %%
df.shape
# Out:
# (1485653, 86)

# %%
df.MORTEPARTO.value_counts()
# Out:
# MORTEPARTO
# 3.0    26025
# 1.0    18791
# 9.0     1478
# 2.0      940
# Name: count, dtype: int64
